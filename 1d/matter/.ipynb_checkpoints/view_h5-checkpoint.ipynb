# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
f = h5py.File('solution.h5', 'r')
list(f.keys())
# Out:
# ['Sol_vec']

# %%
dset = f['Sol_vec']

# %%
data = np.zeros(dset.shape)

# %%
dset.read_direct(data, source_sel=np.s_[:,:], dest_sel=np.s_[:,:])

# %%
dset.shape
# Out:
# (5001, 5000, 2)

# %%
plt.imshow(np.abs(data[:-1,:,0]+1j*data[:-1,:,1]),cmap='jet')
plt.show()

# %%
f.close()
